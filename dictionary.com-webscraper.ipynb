# %%
import requests
from bs4 import BeautifulSoup
import http.cookiejar as cookielib

# %%
r=requests.get("https://www.dictionary.com")
soup=BeautifulSoup(r.content,"html.parser")

# %%
q=input("Enter word: ")
# Out:
# Enter word: rainn

# %%
r=requests.get("https://www.dictionary.com/browse/"+q+"?s=t")

# %%
soup=BeautifulSoup(r.content,"html.parser")
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en" prefix="og: http://ogp.me/ns#">\n <head>\n  <meta charset="utf-8"/>\n  <link as="font" crossorigin="anonymous" href="https://www.dictionary.com/assets/dictionary-font-c864a1ca3bc4a1c7aef16dbbf189ccc1.woff" rel="preload" type="font/woff"/>\n  <meta content="noindex" name="robots"/>\n  <meta content="https://www.dictionary.com/assets/dcom-social-icon-952ee83e140e5bfbd2d4b6c28daa1a8f.png" property="og:image"/>\n  <meta content="www.dictionary.com" property="og:site_name"/>\n  <meta content="127444090629600" property="fb:app_id"/>\n  <meta content="100000304287730;109125464873" property="fb:admins"/>\n  <meta content="DF5542D7723770377E9ABFF59AC1DC97" name="msvalidate.01"/>\n  <link href="https://www.dictionary.com/assets/favicon-1bff2f1b49c077ed504e55c3649f2a4b.png" rel="icon" type="image/png"/>\n  <title>\n   Rainn | Define Rainn at Dictionary.com\n  </title>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <link href="https://ads.pubmatic.com" rel="preconnect"/>\n  <link href="https://www.googletagservices.com" rel="preconnect"/>\n  <link href="https://c.amazon-adsystem.com" rel="preconnect"/>\n  <link href="https://www.googletagmanager.com" rel="preconnect"/>\n  <link href="https://www.google-analytics.com" rel="preconnect"/>\n  <link href="https://connect.facebook.net" rel="preconnect"/>\n  <script defer="" src="https://www.dictionary.com/assets/vendor-251be9b9.js">\n  </script>\n  <script defer="" src="https://www.dictionary.com/assets/client-5828b750.js">\n  </script>\n  <!-- Ad integration with callback begins here, must be in head, expects page type to get appropriate configs -->\n  <script>\n   /** wrapping ad scripts with adboiler label **/\n  adboiler: {\n    \n\n    /**---------- Page level ad targeting configs ----------*/\n    var pageTargeting = {"tx1":"results","tx2":"misspelled_0_n","ptype":"content","ld":"0"};\n\n    /**---------- Page level ad slot configs ----------*/\n    var slotConfigs = [{"placement":"dcom-misspell-lb-728x90","code":"/23219321/iac.dict.dictry.dw/dic-spell/misspelled_0_n","ad_uuid":"728x90_top","targeting":{"pos":"top","pos2":"728x90_1"},"sizes":[[728,90]]},{"placement":"dcom-misspell-top-300x250","code":"/23219321/iac.dict.dictry.dw/dic-spell/misspelled_0_n","ad_uuid":"300x250_top","targeting":{"pos":"top","pos2":"300x250_1"},"sizes":[[300,250]]},{"placement":"dcom-misspell-bottom-lb-728x90","code":"/23219321/iac.dict.dictry.dw/dic-spell/misspelled_0_n","ad_uuid":"728x90_bot","targeting":{"pos":"bot","pos2":"728x90_2"},"sizes":[[728,90]]}];\n    var slotConfigsDeferred = [];\n\n    var googletag = googletag || {};\n    googletag.cmd = googletag.cmd || [];\n    var adSlots =  adSlots || {slots:{}, lazySlots:{}};\n\n    const setupDFP = function() {\n      console.log(\'Setting up DFP\');\n      /**---------- Set page level targeting for DFP ----------*/\n      for (var pageTarget in pageTargeting) {\n        if (pageTargeting.hasOwnProperty(pageTarget)) {\n          (function(key, value) {\n            googletag.cmd.push(function() {\n              googletag.pubads().setTargeting(key, value);\n            });\n          })(pageTarget, pageTargeting[pageTarget]);\n        }\n      }\n\n      /**---------- Set ad slot level targeting for DFP ----------*/\n      if (typeof slotConfigs === "object") {\n        slotConfigs.forEach(function(slot, index) {\n          googletag.cmd.push(function() {\n            adSlots.slots[slot.placement] = googletag.defineSlot(slot.code, slot.sizes, slot.placement).addService(googletag.pubads());\n            for (var target in slot.targeting) {\n              if (slot.targeting.hasOwnProperty(target)) {\n                adSlots.slots[slot.placement].setTargeting(target, slot.targeting[target]);\n              }\n            }\n          });\n        });\n      }\n\n      /**---------- Push gpt ad slots to DFP ----------*/\n      googletag.cmd.push(function() {\n        googletag.pubads().enableSing ...

# %%
soup.find_all("li",{"class":"css-ohz4fb e19m0k9k5"})[1].text
# Out:
# 'rani'
